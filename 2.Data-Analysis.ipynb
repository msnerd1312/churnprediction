# %% [markdown]
# # Customer churn analysis
#
# ## Exploratory data analysis (EDA)
#
# This demo is continuation of the telco pipeline after data load, clean and transformation. We will now try to explore data using snowpark and other python library. This task help us identify further transformations, importatn variable discovery and any feature engineering thats required later.
#
# ## Analysis
#
# **We will analyse the following:**
#
# 1. The target variable
# 2. Variable types (categorical and numerical)
# 3. Missing data
# 4. Numerical variables
#     - Discrete
#     - Continuous
#     - Distributions
#     - Transformations
#
# 5. Categorical variables
#     - Cardinality
#     - Rare Labels
#     - Special mappings

# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark import functions as F
from snowflake.snowpark.types import *

import pandas as pd

from sklearn import linear_model

import matplotlib.pyplot as plt

# %matplotlib inline
import datetime as dt
import numpy as np
import seaborn as sns
import json

#Snowflake connection info
from config import snowflake_conn_prop

import warnings
warnings.filterwarnings("ignore")

# lets import some tranformations functions
from snowflake.snowpark.functions import udf, col, lit, translate, is_null, iff

# %%
from snowflake.snowpark import version
print(version.VERSION)

# connect to Snowflake
with open("secrets.json", "r") as f:
    snowflake_conn_prop = json.load(f)  
session = Session.builder.configs(snowflake_conn_prop).create()
print(session.sql('select current_warehouse(), current_database(), current_schema()').collect())
# Out:
# (1, 11, 1)
# [Row(CURRENT_WAREHOUSE()='SNOWPARK_WH', CURRENT_DATABASE()='CHURN_DB', CURRENT_SCHEMA()='CHURN_SCHEMA')]

# %%
# %%time

raw = session.table('TRAIN_DATASET_BIN')
data = raw.toPandas()
# Out:
# CPU times: user 670 ms, sys: 52.2 ms, total: 722 ms
# Wall time: 2.78 s

# %%
# to display all the columns of the dataframe in the notebook
#pd.pandas.set_option('display.max_columns', None)
data.head(5)
# Out:
#    CUSTOMERID  GENDER SENIORCITIZEN PARTNER DEPENDENTS  TENUREMONTHS  \
# 0  WwrUeyguhu  Female            No      No        Yes             2
# 1  DNuFFvxO8O  Female            No      No        Yes             8
# 2  xeiCbPqYpb    Male           Yes      No        Yes            18
# 3  NJBFBr8oKJ    Male            No      No        Yes             3
# 4  xu9UDKawli  Female            No      No        Yes            13
#
#   PHONESERVICE MULTIPLELINES INTERNETSERVICE ONLINESECURITY  ...  \
# 0          Yes            No     Fiber optic             No  ...
# 1          Yes           Yes     Fiber optic             No  ...
# 2          Yes           Yes     Fiber optic             No  ...
# 3          Yes           Yes     Fiber optic             No  ...
# 4          Yes            No     Fiber optic             No  ...
#
#   STREAMINGMOVIES        CONTRACT PAPERLESSBILLING     PAYMENTMETHOD  \
# 0              No  Month-to-month              Yes  Electronic check
# 1             Yes  Month-to-month              Yes  Electronic check
# 2             Yes  Month-to-month              Yes  Electronic check
# 3              No  Month-to-month              Yes  Electronic check
# 4              No  Month-to-month              Yes  Electronic check
#
#   MONTHLYCHARGES TOTALCHARGES TENUREMONTHSBIN MONTHLYCHARGESBIN  \
# 0          70.70       151.65             Low               Low
# 1          99.65       820.50          Medium            Medium
# 2          95.45      1752.55             Low            Medium
# 3          74.40       229.55          Medium               Low
# 4          79.25      1111.65             Low            Medium
#
#    TOTALCHARGESBIN  CHURNVALUE
# 0              Low           1
# 1              Low           1
# 2              Low           1
# 3              Low           1
# 4              Low           1
#
# [5 rows x 24 columns]

# %%
shape = data.shape
print(shape)
# Out:
# (100000, 24)

# %% [markdown]
# ## Check Target Distribution
#
# Let's begin by exploring the target distribution.

# %%
# We'll print the target variable, target names, and frequency of each unique value:

(unique, counts) = np.unique(data['CHURNVALUE'], return_counts=True)

print('Unique values of target variable', unique)
print('Counts of target variable', counts)
# Out:
# Unique values of target variable [0 1]
# Counts of target variable [67774 32226]

# %%
sns.barplot(x=unique, y=counts)
plt.title('Target variable counts in dataset')
plt.show()

# %% [markdown]
# ## Step 1: Define explonatory variables and target variable

# %%
data.head(4)
# Out:
#    CUSTOMERID  GENDER SENIORCITIZEN PARTNER DEPENDENTS  TENUREMONTHS  \
# 0  WwrUeyguhu  Female            No      No        Yes             2
# 1  DNuFFvxO8O  Female            No      No        Yes             8
# 2  xeiCbPqYpb    Male           Yes      No        Yes            18
# 3  NJBFBr8oKJ    Male            No      No        Yes             3
#
#   PHONESERVICE MULTIPLELINES INTERNETSERVICE ONLINESECURITY  ...  \
# 0          Yes            No     Fiber optic             No  ...
# 1          Yes           Yes     Fiber optic             No  ...
# 2          Yes           Yes     Fiber optic             No  ...
# 3          Yes           Yes     Fiber optic             No  ...
#
#   STREAMINGMOVIES        CONTRACT PAPERLESSBILLING     PAYMENTMETHOD  \
# 0              No  Month-to-month              Yes  Electronic check
# 1             Yes  Month-to-month              Yes  Electronic check
# 2             Yes  Month-to-month              Yes  Electronic check
# 3              No  Month-to-month              Yes  Electronic check
#
#   MONTHLYCHARGES TOTALCHARGES TENUREMONTHSBIN MONTHLYCHARGESBIN  \
# 0          70.70       151.65             Low               Low
# 1          99.65       820.50          Medium            Medium
# 2          95.45      1752.55             Low            Medium
# 3          74.40       229.55          Medium               Low
#
#    TOTALCHARGESBIN  CHURNVALUE
# 0              Low           1
# 1              Low           1
# 2              Low           1
# 3              Low           1
#
# [4 rows x 24 columns]

# %%
# let's identify the categorical variables
# we will capture those of type *object* and boolean
cat_vars = [var for var in data.columns if ((data[var].dtype == 'O') or (data[var].dtype=="bool"))]

# Remove misinterpreted objects like "CustomerID"
cat_vars.pop(0)

print(cat_vars)
# Out:
# ['GENDER', 'SENIORCITIZEN', 'PARTNER', 'DEPENDENTS', 'PHONESERVICE', 'MULTIPLELINES', 'INTERNETSERVICE', 'ONLINESECURITY', 'ONLINEBACKUP', 'DEVICEPROTECTION', 'TECHSUPPORT', 'STREAMINGTV', 'STREAMINGMOVIES', 'CONTRACT', 'PAPERLESSBILLING', 'PAYMENTMETHOD', 'TENUREMONTHSBIN', 'MONTHLYCHARGESBIN', 'TOTALCHARGESBIN']

# %%
# Define a list of data types that you consider as categorical
#categorical_data_types = ['STRING', 'BOOLEAN']

# Identify categorical variables based on data types
#cat_vars = [var for var, dtype in zip(data.columns, data.dtypes) if dtype in categorical_data_types]

# Remove misinterpreted objects like "CUSTOMERID"
#if 'CUSTOMERID' in cat_vars:
    #cat_vars.remove('CUSTOMERID')

#print(cat_vars)

# %%
# now let's identify the numerical variables
num_vars = [var for var in data.columns if var not in cat_vars and var != 'CHURNVALUE' and 'CUSTOMERID' not in var]

# number of numerical variables
print(num_vars)
# Out:
# ['TENUREMONTHS', 'MONTHLYCHARGES', 'TOTALCHARGES']

# %%
# lets plot histograms for all continuous variables
print(data[num_vars].head())
data[num_vars].hist(bins=30, figsize=(15,15))
plt.show()
# Out:
#    TENUREMONTHS  MONTHLYCHARGES  TOTALCHARGES
# 0             2           70.70        151.65
# 1             8           99.65        820.50
# 2            18           95.45       1752.55
# 3             3           74.40        229.55
# 4            13           79.25       1111.65

# %% [markdown]
# # Missing values
#
# Let's go ahead and find out which variables of the dataset contain missing values.

# %%
# make a list of the variables that contain missing values
vars_with_na = [var for var in data.columns if data[var].isnull().sum() > 0]

# determine percentage of missing values (expressed as decimals)
# and display the result ordered by % of missin data

data[vars_with_na].isnull().mean().sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Numerical variables
#
# Let's go ahead and find out what numerical variables we have in the dataset

# %%
print('Number of numerical variables: ', len(num_vars))

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
num_df = data[num_vars]
scaler.fit(num_df,y=None)

# visualise the numerical variables
num_df.head()
# Before Transformation
# Out:
# Number of numerical variables:  3
#    TENUREMONTHS  MONTHLYCHARGES  TOTALCHARGES
# 0             2           70.70        151.65
# 1             8           99.65        820.50
# 2            18           95.45       1752.55
# 3             3           74.40        229.55
# 4            13           79.25       1111.65

# %%
# lets plot histograms for all continuous variables after they are scaled
new_df = pd.DataFrame(scaler.transform(num_df),columns=data[num_vars].columns)

#new_df2 = pd.DataFrame(np.log(new_df),columns=data[num_vars].columns)
new_df.head()
new_df.hist(bins=50, figsize=(20,20))
plt.show()

# %% [markdown]
# ## Taking care of outliers

# %%
def drop_outliers(df,out_name):
    iqr = 1.5 * (np.percentile(df[out_name], 75) - np.percentile(df[out_name], 25))
    df.drop(df[df[out_name] > (iqr + np.percentile(df[out_name], 75))].index, inplace=True)
    df.drop(df[df[out_name] < (np.percentile(df[out_name], 25) - iqr)].index, inplace=True)
    

drop_outliers(data,'TENUREMONTHS')
drop_outliers(data,'MONTHLYCHARGES')
drop_outliers(data,'TOTALCHARGES')

# %%
sns.boxplot(x=data['MONTHLYCHARGES'])
plt.show()

# %% [markdown]
# # Categorical variables
#
# Let's go ahead and analyse the categorical variables present in the dataset.

# %%
print('Number of categorical variables: ', len(cat_vars))
# Out:
# Number of categorical variables:  19

# %%
# let's preview the categorical variables
data[cat_vars].head()
# Out:
#    GENDER SENIORCITIZEN PARTNER DEPENDENTS PHONESERVICE MULTIPLELINES  \
# 0  Female            No      No        Yes          Yes            No
# 1  Female            No      No        Yes          Yes           Yes
# 2    Male           Yes      No        Yes          Yes           Yes
# 3    Male            No      No        Yes          Yes           Yes
# 4  Female            No      No        Yes          Yes            No
#
#   INTERNETSERVICE ONLINESECURITY ONLINEBACKUP DEVICEPROTECTION TECHSUPPORT  \
# 0     Fiber optic             No           No               No          No
# 1     Fiber optic             No           No              Yes          No
# 2     Fiber optic             No           No               No          No
# 3     Fiber optic             No           No               No          No
# 4     Fiber optic             No          Yes              Yes          No
#
#   STREAMINGTV STREAMINGMOVIES        CONTRACT PAPERLESSBILLING  \
# 0          No              No  Month-to-month              Yes
# 1         Yes             Yes  Month-to-month              Yes
# 2         Yes             Yes  Month-to-month              Yes
# 3          No              No  Month-to-month              Yes
# 4          No              No  Month-to-month              Yes
#
#       PAYMENTMETHOD TENUREMONTHSBIN MONTHLYCHARGESBIN TOTALCHARGESBIN
# 0  Electronic check             Low               Low             Low
# 1  Electronic check          Medium            Medium             Low
# 2  Electronic check             Low            Medium             Low
# 3  Electronic check          Medium               Low             Low
# 4  Electronic check             Low            Medium             Low

# %% [markdown]
# ## Number of labels: cardinality
#
# Let's evaluate how many different categories are present in each of the variables.

# %%
# get the number of unique values (cardinality) for each categorical variable

data[cat_vars].nunique().sort_values(ascending=False).plot.bar(figsize=(12,5));

# %% [markdown]
# ## Rare labels:
#
# Let's go ahead and investigate now if there are labels that are present only in a small number of customers:

# %%
print(cat_vars)
def analyse_rare_labels(df, var, rare_perc):
    df = df.copy()

    # determine the % of observations per category
    tmp = df.groupby(var)['CHURNVALUE'].count() / len(df)

    # return categories that are rare
    return tmp[tmp < rare_perc]

# print categories that are present in less than
# 1 % of the observations

for var in cat_vars:
    print(analyse_rare_labels(data, var, 0.01))
    print()
# Out:
# ['GENDER', 'SENIORCITIZEN', 'PARTNER', 'DEPENDENTS', 'PHONESERVICE', 'MULTIPLELINES', 'INTERNETSERVICE', 'ONLINESECURITY', 'ONLINEBACKUP', 'DEVICEPROTECTION', 'TECHSUPPORT', 'STREAMINGTV', 'STREAMINGMOVIES', 'CONTRACT', 'PAPERLESSBILLING', 'PAYMENTMETHOD', 'TENUREMONTHSBIN', 'MONTHLYCHARGESBIN', 'TOTALCHARGESBIN']
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)

# %% [markdown]
# ### So all the cat variables are distributed well

# %%
data[cat_vars].shape, data[num_vars].shape, data['CHURNVALUE'].shape
# Out:
# ((99961, 19), (99961, 3), (99961,))

# %%
# final columns that we want in our training data set are cat, num and target variables
final_cols = cat_vars + num_vars + ['CHURNVALUE']
final_cols
# Out:
# ['GENDER',
#  'SENIORCITIZEN',
#  'PARTNER',
#  'DEPENDENTS',
#  'PHONESERVICE',
#  'MULTIPLELINES',
#  'INTERNETSERVICE',
#  'ONLINESECURITY',
#  'ONLINEBACKUP',
#  'DEVICEPROTECTION',
#  'TECHSUPPORT',
#  'STREAMINGTV',
#  'STREAMINGMOVIES',
#  'CONTRACT',
#  'PAPERLESSBILLING',
#  'PAYMENTMETHOD',
#  'TENUREMONTHSBIN',
#  'MONTHLYCHARGESBIN',
#  'TOTALCHARGESBIN',
#  'TENUREMONTHS',
#  'MONTHLYCHARGES',
#  'TOTALCHARGES',
#  'CHURNVALUE']

# %%
# %%time
snowpark_train_df = session.write_pandas(data[final_cols], 'TELCO_TRAIN_SET_BIN', auto_create_table=True, overwrite=True)
# Out:
# CPU times: user 370 ms, sys: 32 ms, total: 402 ms
# Wall time: 6.63 s

# %%
snowpark_train_df.toPandas()
# Out:
#        GENDER SENIORCITIZEN PARTNER DEPENDENTS PHONESERVICE MULTIPLELINES  \
# 0      Female            No      No        Yes          Yes            No
# 1      Female            No      No        Yes          Yes           Yes
# 2        Male           Yes      No        Yes          Yes           Yes
# 3        Male            No      No        Yes          Yes           Yes
# 4      Female            No      No        Yes          Yes            No
# ...       ...           ...     ...        ...          ...           ...
# 99956    Male            No     Yes         No          Yes           Yes
# 99957  Female            No     Yes         No          Yes            No
# 99958  Female            No     Yes        Yes          Yes           Yes
# 99959  Female            No     Yes         No          Yes            No
# 99960    Male            No     Yes        Yes          Yes           Yes
#
#       INTERNETSERVICE       ONLINESECURITY         ONLINEBACKUP  \
# 0         Fiber optic                   No                   No
# 1         Fiber optic                   No                   No
# 2         Fiber optic                   No                   No
# 3         Fiber optic                   No                   No
# 4         Fiber optic                   No                  Yes
# ...               ...                  ...                  ...
# 99956             DSL                  Yes                  Yes
# 99957             DSL                   No                  Yes
# 99958     Fiber optic                  Yes                  Yes
# 99959              No  No internet service  No internet service
# 99960     Fiber optic                   No                  Yes
#
#           DEVICEPROTECTION  ...        CONTRACT PAPERLESSBILLING  \
# 0                       No  ...  Month-to-month              Yes
# 1                      Yes  ...  Month-to-month              Yes
# 2                       No  ...  Month-to-month              Yes
# 3                       No  ...  Month-to-month              Yes
# 4                      Yes  ...  Month-to-month              Yes
# ...                    ...  ...             ...              ...
# 99956                   No  ...  Month-to-month               No
# 99957                  Yes  ...        Two year              Yes
# 99958                  Yes  ...        Two year              Yes
# 99959  No internet service  ...        Two year               No
# 99960                  Yes  ...        One year              Yes
#
#                    PAYMENTMETHOD TENUREMONTHSBIN MONTHLYCHARGESBIN  \
# 0               Electronic check             Low               Low
# 1               Electronic check          Medium            Medium
# 2               Electronic check             Low            Medium
# 3               Electronic check          Medium               Low
# 4               Electronic check             Low            Medium
# ...                          ...             ...               ...
# 99956  Bank transfer (automatic)             Low            Medium
# 99957    Credit card (automatic)          Medium               Low
# 99958  Bank transfer (automatic)            High               Low
# 99959    Credit card (automatic)             Low            Medium
# 99960           Electronic check             Low            Medium
#
#       TOTALCHARGESBIN TENUREMONTHS MONTHLYCHARGES TOTALCHARGES  CHURNVALUE
# 0                 Low            2          70.70       151.65           1
# 1                 Low            8          99.65       820.50           1
# 2                 Low           18          95.45      1752.55           1
# 3                 Low            3          74.40       229.55           1
# 4                 Low           13          79.25      1111.65           1
# ...               ...          ...            ...          ...         ...
# 99956            High           43          66.25      2907.35           0
# 99957          Medium           71          80.70      5705.05           0
# 99958             Low           53         104.05      5566.40           0
# 99959             Low           61          20.25      1278.80           0
# 99960             Low           49          93.65      4520.15           0
#
# [99961 rows x 23 columns]

# %% [markdown]
# # Off to training a model and deplyment

# %%
session.close()
